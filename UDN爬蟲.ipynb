# %% [markdown]
# <a href="https://colab.research.google.com/github/bmeelnlga/myportfolio/blob/main/UDN%E7%88%AC%E8%9F%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import time
import json

class UDN:

  def __init__(self, page: int, start_url: str, start_id: int) -> None:
      self.page = page  # 要爬取的文章數
      self.start_url = start_url  # 基礎 URL
      self.start_id = start_id  # 開始的文章 ID
      self.article_list = []  # 存儲爬取的文章

  def fetch_data(self, url: str):
      """抓取網頁數據並返回未處理的 BeautifulSoup 對象"""
      try:
          response = requests.get(url)
          response.raise_for_status()  # 檢查請求是否成功
          soup = BeautifulSoup(response.text, 'html.parser')
          return soup
      except requests.RequestException as e:
          print(f"Error fetching data from {url}: {e}")
          return None

  def get_content(self, soup: BeautifulSoup):
      """提取文章的正文內容並去除 \n 和 \r"""
      contents = soup.findAll('p', class_=None)
      if contents:
          result = " ".join(content.text.replace('\n', '').replace('\r', '').strip() for content in contents)
          return result
      return None

  def get_datetime(self, soup: BeautifulSoup):
      """提取發佈日期"""
      datetime_tag = soup.find(class_='article-content__time')
      return datetime_tag.text.split(" ")[0] if datetime_tag else None

  def get_category(self, soup: BeautifulSoup):
      """提取文章的類別"""
      category_tag = soup.find('meta', {'property': 'article:section'})  # 根據網站的標籤結構進行調整
      return category_tag['content'] if category_tag else None

  def get_subtitle(self, soup: BeautifulSoup):
      """取文章的副標題 (如: 金融要聞)"""
      # 查找類名為 'breadcrumb-items' 且沒有 href 屬性的 <a> 標籤
      subtitle_tag = soup.find('a', class_='breadcrumb-items', href=False)

  # 返回副標題文字，如果找不到則返回 None
      return subtitle_tag.text.strip() if subtitle_tag else None


  def get_title(self, soup: BeautifulSoup):
      """提取文章標題"""
      title_tag = soup.find('h1')
      return title_tag.text.strip() if title_tag else None

  def get_comments(self, soup: BeautifulSoup):
      """提取留言數量"""
      comments_tag = soup.find(class_='article-comments')
      return comments_tag.text.strip().split(" ")[0] if comments_tag else "0"

  def get_info(self):
      """循環抓取文章信息並儲存"""
      for i in range(self.start_id - self.page, self.start_id):
          article_url = self.start_url + str(i)
          soup = self.fetch_data(article_url)

          if soup:
              category=self.get_category(soup)
              title= self.get_title(soup)
              datetime= self.get_datetime(soup)
              link=article_url
              content= self.get_content(soup)
              comments= self.get_comments(soup)
              subtitle= self.get_subtitle(soup)
              if title is None or content is None:
                  print(f"Skipping article ID {i} due to missing title or content.")
                  continue  # 跳過這篇文章

              article_content = {
                  "category": category,
                  "subtitle": subtitle,
                  "title": title,
                  "datetime": datetime,
                  "link": link,
                  "content": content,
                  "comments": comments,
              }

              self.article_list.append(article_content)  # 儲存文章信息
              print(json.dumps(article_content, ensure_ascii=False, indent=4))  # 打印 JSON 格式的文章信息

          time.sleep(0.3)  # 延時避免過快爬取

      # 儲存所有文章信息到 JSON 文件
      with open("udn_articles.json", "w", encoding='utf-8') as f:
          json.dump(self.article_list, f, ensure_ascii=False, indent=4)

udn = UDN(10, "https://udn.com/news/story/124222/", 8716497) # 測試爬取10篇文章
udn.get_info()
# Out:
# <ipython-input-7-c2576632db29>:27: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   contents = soup.findAll('p', class_=None)
# {
#     "category": "生活",
#     "subtitle": "生活新聞",
#     "title": "首批「萊豬」輸台恐引一波食安風暴？ 食藥署最新說明",
#     "datetime": "2025-05-04",
#     "link": "https://udn.com/news/story/124222/8716487",
#     "content": "根據衛福部食藥署「豬肉儀表板」顯示，4月29日有一批從澳洲進口的22.99公噸豬其他可食部位，被檢出還有0.001PPM萊克多巴胺，引發各界擔憂，是否會有食安風險？食藥署表示，這批產品的萊劑殘留容許量在0.01PPM內，屬於可接受風險。  食藥署指出，近期食藥署邊境受理報驗澳洲「冷凍豬腳」1批（淨重2萬2991公斤），該批貨品依規定查驗並抽樣送驗乙型受體素，檢出萊克多巴胺0.001 PPM，符合「動物用藥殘留標準」於該類產品之殘留容許量0.01PPM，已於4月29日依規定核發輸入許可通知，並顯示於「豬肉儀表板」，所有合格放行案件，都在科學分析下可接受風險。  這是台灣開放萊豬進口後，首批含有萊克多巴胺的進口豬肉，食藥署強調，這一批肉品輸入產品符合「動物用藥殘留標準」，經輸入查驗合格放行，得於國內銷售流通。目前如此，未來也持續依「食安優先、科學分析、國際標準及市場稽查」辦理。  政府對於進口豬肉（含萊劑豬肉）於110年1月起，針對可輸入之生鮮冷藏冷凍豬肉產品，不分國別，採逐批查驗措施，經查驗符合規定始得輸入。食藥署強調，自110年1月1日起輸入豬肉產品，採逐批監視查驗，並持續依風險滾動調整查驗方式，現行各國輸入之豬肉產品，採一般抽批查驗。 ▪ 手機報稅超簡單！4步驟輕鬆搞定 一圖看節稅祕訣不卡關 根據衛福部食藥署「豬肉儀表板」顯示，4月29日有一批從澳洲進口的22.99公噸豬其他可食部位，被檢出還有0.001PPM... 4月29日一批22.99公噸自澳洲進口的豬其他可食部位，檢出0.001PPM萊克多巴胺，這也是台灣開放萊豬進口後，首批含... 周五晚上，北美館前豎起一根根閃亮的鋁管，不斷噴灑霧氣，彷彿要為即將進入夏季的城市降溫。這是北美館第12屆「X-site計... 為降低行人死亡，交通部今年祭出改善道安三支箭，其中包含改善路口照明，以「路段黃光、路口白光」為更換原則，選定全台7處行人... 不長脾氣長智慧！科博特診所院長劉博仁近日在臉書貼文，引用《美國心臟協會期刊》研究指出，短時間的強烈憤怒，可能對心血管系統造成急性傷害。 高麗菜近期價格親民，成為民眾採購常見選項。旅日作家「魚漿夫婦」近日分享一篇來自日本農民的貼文，指出高麗菜在生長過程中會先形成小球狀，再逐層向外擴大，因此內層葉片通常乾淨、不需逐片清洗，就像洋蔥一樣。然而貼文曝光後，有內行表示，以台灣的種植條件來看，可能沒辦法像日本一樣，最好還是一片一片洗，食用相對安全。",
#     "comments": "0"
# }
# {
#     "category": "要聞",
#     "subtitle": "大罷免議題延燒",
#     "title": "批趙少康聲援罷免吳沛憶 綠轟仇恨動員淪「惡鬥藍」",
#     "datetime": "2025-05-04",
#     "link": "https://udn.com/news/story/124222/8716488",
#     "content": "罷免民進黨立委吳沛憶進入二階連署，資深媒體人趙少康昨與前市長郝龍斌等到青年公園擺攤徵求連署；挺吳沛憶的民進黨中正萬華議員擬參選人康家瑋今則掛上反罷看板，質疑趙少康劣跡斑斑，造謠慣犯卻來聲援罷免，令人看不下去，痛批仇恨動員讓戰鬥藍淪「惡鬥藍」。  罷免立委吳沛憶案進入第二階段連署，康家瑋表示，吳沛憶從就任立委以來，無論是問政實績或地方建設都可圈可點，藍白在立法院亂砍預算、亂提惡法時，吳也都在第一時間挺身而出、不畏藍白碾壓，他奉勸趙少康，要來聲援罷免吳沛憶前應先到中正萬華走一圈，一定可以看到吳沛憶的各種政績、感受到鄉親的支持。  康指出，趙少康過去競選副總統時，曾造謠台積電前董事長劉德音退休是因民進黨壓力，一度引起各界批評，而在落選後，自稱身為媒體人不會參與政治活動的趙少康，卻跑去參加挺違法的426凱道集會，他痛批，趙少康的政治誠信早已蕩然無存，如今為了刷存在感跑來罷免優質立委，為罷而罷的仇恨動員，中正萬華鄉親絕對不會接受。  康家瑋也呼籲中正萬華鄉親，抵制吳沛憶罷免案、為在地守住優質立委，不要讓有心人士得逞、更不要讓中正萬華成為藍白政治分贓的戰場，他強調，為國家割除藍白毒瘤、還給台灣一個得以理性論政的立法院，就看這次大罷免。 南投一向被視為藍營鐵票倉，罷免國民黨立委難度高，但繼投二「去游除垢」罷免游顥公民團體前天送件後，3天前才因連署書仍不足千... 新竹市長高虹安、立委鄭正鈐雙雙面臨罷免，新竹市雙罷總部今公布連署份數．這次收到罷免高虹安和鄭正鈐的總份數突破10萬份，總... 罷免民進黨立委吳沛憶進入二階連署，資深媒體人趙少康昨與前市長郝龍斌等到青年公園擺攤徵求連署；挺吳沛憶的民進黨中正萬華議員... 罷免基隆市立委林沛祥案的領銜人陳青逸，今天近午和魏姓志工在公車循環站旁，號召民眾參與連署時，1名男子認為宣傳聲音吵到他，... 罷免綠委吳思瑤二階連署中，張克晉日前宣布退出領銜人身分，召集人賴苡任日前在網路節目透露，想過任何可能性，包括重起罷免案，... 大罷免行動持續，不少遭提罷免的立委感慨，因無法募款，自掏腰包壓力大。國民黨首席副書記長羅智強表示，他將捐出自己新書總書款...",
#     "comments": "0"
# }
# Skipping article ID 8716489 due to missing title or content.
# Skipping article ID 8716490 due to missing title or content.
# {
#     "category": "要聞",
#     "subtitle": "大罷免議題延燒",
#     "title": "牛煦庭籲罷團辦辯論 領銜人待5日2階送件再回應",
#     "datetime": "2025-05-04",
#     "link": "https://udn.com/news/story/124222/8716491",
#     "content": "國民黨立委牛煦庭今天發文向桃園市第一選區罷免團體領銜人陳曉煒喊話，籲辦公開辯論會，在選民面前把爭議說清楚。陳曉煒表示，今天要做最後查對，明天2階送件記者會再回應。 牛煦庭上午在臉書（Facebook）以「用真正的民主，樹立桃園第一選區的典範」為題發文表示，前段時間因忙於質詢、法案，對連署充分尊重。依據罷團安排第2階段連署書將於明天送出，即將進入40天的查對期，「在我看來，沒有比眼下更好的時機，能把質疑論個清楚，能讓真相完整呈現在人民的眼前。」 對此，桃園第一選區罷免牛煦庭公民團體領銜人陳曉煒回應，今天是星期日，預定明天送件，今天還要做最後查對，將於第2階段連署書送件記者會一併回應。 牛煦庭說，選舉應該辯論，不同候選人的政見或有歧異，而各自發表，不見得能論實力高低，唯有真刀真槍的辯論，才是政治人物是否適格的試金石。罷免更應該辯論，罷免標榜的是公民權利的實踐。罷免團體對他的12項指控，在第2階段送件之際他自當認真回應，但不該只是各說各話。 牛煦庭指出，陳曉煒身為難以取代的領銜人，有義務認真聆聽他的辯解，他身為被罷免人，也有義務現場回答陳曉煒的疑慮。雙方應共同舉辦公開的辯論會，在選民面前把爭議說清楚。 他認為，真理越辯越明、場次越多越好，才可讓資訊的呈現能對稱、讓客觀的事實能彰顯、讓選民的理性決定最後成敗。 牛煦庭表示，去年5月開始，在他立委任期還未滿半年，陳曉煒就開始倡議罷免，很多「政治片段」被斷章取義在網路、政論節目、記者會上擴散。接下來的100天，能不能讓桃園市第一選區有個建立「民主典範」的機會，公開辯論的場次、時間、地點、形式都可商量，希望陳曉煒在明天送件之餘，能接下這合理要求。 南投一向被視為藍營鐵票倉，罷免國民黨立委難度高，但繼投二「去游除垢」罷免游顥公民團體前天送件後，3天前才因連署書仍不足千... 新竹市長高虹安、立委鄭正鈐雙雙面臨罷免，新竹市雙罷總部今公布連署份數．這次收到罷免高虹安和鄭正鈐的總份數突破10萬份，總... 罷免民進黨立委吳沛憶進入二階連署，資深媒體人趙少康昨與前市長郝龍斌等到青年公園擺攤徵求連署；挺吳沛憶的民進黨中正萬華議員... 罷免基隆市立委林沛祥案的領銜人陳青逸，今天近午和魏姓志工在公車循環站旁，號召民眾參與連署時，1名男子認為宣傳聲音吵到他，... 罷免綠委吳思瑤二階連署中，張克晉日前宣布退出領銜人身分，召集人賴苡任日前在網路節目透露，想過任何可能性，包括重起罷免案，... 大罷免行動持續，不少遭提罷免的立委感慨，因無法募款，自掏腰包壓力大。國民黨首席副書記長羅智強表示，他將捐出自己新書總書款...",
#     "comments": "0"
# }
# {
#     "category": "社會",
#     "subtitle": "法律前線",
#     "title": "高雄騎士自摔碰撞行人 恐遭罰款及吊扣駕照",
#     "datetime": "2025-05-04",
#     "link": "https://udn.com/news/story/124222/8716492",
#     "content": "石姓男子昨天騎機車行經高雄路口時，2名路人從路旁違規停放大貨車前走出要過馬路，石男煞車打滑自摔與2人發生碰撞，幸3人輕傷，石男恐遭開罰並吊扣駕照1年，肇因待釐清。  高雄市警察局三民第二分局員警指出，61歲石男昨天下午1時30分許騎機車沿三民區陽明路由北往南行駛，見2名未成年人由路旁1輛違規停放大貨車前走出，並行走斑馬線由西向東穿越馬路，石男緊急煞車不慎打滑自摔，機車滑行與2名行人發生碰撞。  警方表示，事故造成石男與2名行人手腳擦挫傷，經送醫治療無大礙，石男經檢測沒有酒駕。警方初步研判，石男駕駛行近行人穿越道，有行人穿越時，不暫停讓行人先行通過因而致人受傷，涉違反道路交通管理處罰條例第44條第4項，可處新台幣7200元以上、3萬6000元以下罰鍰，並吊扣駕駛執照1年。  警方指出，至於事故現場違規停放在路口處的大貨車，則涉嫌違反道路交通管理處罰條例第56條1項1款，可處600元以上、1200元以下罰鍰，肇因將由交通大隊進一步分析研判，並呼籲民眾行經路口務必放慢車速，留意車流狀況並遵守道路交通標誌、標線、號誌指示，注意前方動態，確保行車安全。 律師呂秋遠經常在臉書分享社會時事與兩性感情觀點，日前法院裁定指出他已認領未成年子女，爆出私生子風波後，呂發文指「媽媽都沒... 桃園黎姓男子疑因高中教官逼退而遭退學，去年4月趁著赴澳洲打工換宿時，以為人在國外寄恐嚇信鐵定查不到，不過警方調閱郵件聲請... 罷免綠委吳思瑤團體「地動刪瑤」領銜人張克晉日前突然發聲明退出領銜人身分，因擔任罷免王定宇領銜人而遭南檢偵辦的胡永融指出，... 高雄市一名施姓男子10年前與小芳（化名）交往成男女朋友，但1年多後就分手，沒想到分手7年之後， 施男竟把小芳的裸照散布到... 陳姓男子駕駛小貨車右轉時，見路口有行人要通過行人穿越道，他先暫停，2秒後卻加速通過，遭後方警車追上攔下開罰。陳不服提告，... 周姓、呂姓、吳姓男子昨凌晨在台北市某酒吧喝酒，周、呂與店員李姓男子起衝突，分持開山刀及酒杯攻擊，造成李左手及頭部受傷，吳...",
#     "comments": "0"
# }
# {
#     "category": "全球",
#     "subtitle": "美國新聞",
#     "title": "方濟各才辭世…川普曬教宗服AI照挨轟！副手范斯急護航「玩笑而已」",
#     "datetime": "2025-05-04",
#     "link": "https://udn.com/news/story/124222/8716493",
#     "content": "美國總統川普2日在社群曬出自己身穿教宗服的照片，引發部分宗教人士甚至共和黨人批評有所冒犯。對此副總統范斯3日在社群發文護航川普，認為這不過是笑話「沒有問題」。  川普在自家「真實社群」分享一張疑似人工智慧（AI）生成的彩色照片，其中川普身穿教宗禮服，伸出右手食指並指向上方，除此之外並未附上任何文字說明。  政治新聞網POLITICO報導，紐約州天主教會議（New York State Catholic Conference）在X發文批評表示：「總統先生，這張照片一點也不好笑，教宗方濟各才剛入土為安，樞機主教即將舉行神聖的秘密會議。請不要拿我們開玩笑。」白宮隨後也轉發這則貼文。  紐約時報報導，共和黨全國委員會（Republican National Committee）前主席史蒂爾（Michael Steele）也稱川普貼文「不正經、表現無能」。  不過，副總統范斯3日在X發文，回應新聞意見網站The Bulwark問及「能否接受聖父遭受不尊重和嘲笑」時，他表示：「一般來說，我對別人開玩笑沒有問題，但對於挑起愚蠢戰爭，造成成千上萬同胞喪命，我不能接受。」  教宗方濟各於4月21日辭世，享壽88歲，他辭世前一日才接見范斯，儘管兩人因移民和教義問題公開分歧，但互動過程平和、充滿善意；范斯也成為方濟各最後正式接見的外國政要之一。  教廷訂於5月7日開始新教宗選舉會議。  川普本周稍早才對記者開玩笑說，他想成為下一任教宗。不過他又接著說，自己沒有偏好，但紐約有一位「非常好的」樞機主教。   ▪此時不買股更待何時？巴菲特最愛指標亮綠燈 ▪俄黑海港口城市遇襲進入緊急狀態 無人機攻擊碼頭大樓畫面曝光 ▪皮卡和賓士相撞全毀！黃石公園附近嚴重車禍 6華人旅客身亡 ▪不當總統了？川普才笑喊「想成為教宗」今曬穿教宗服、食指向天照 ▪Nike、Adidas帶頭喊話！美76家鞋業連署求川普「放鞋一馬」 美國總統川普2日在社群曬出自己身穿教宗服的照片，引發部分宗教人士甚至共和黨人批評有所冒犯。對此副總統范斯3日在社群發文護... 美國司法部2日違抗法院命令，拒絕解封涉及市長亞當斯(Eric Adams)貪腐案的關鍵文件。盡管該案件已無可能進入審判程... 國務卿魯比歐(Marco Rubio)2日在社交媒體上貼文表示，不論來美國旅遊或是居住於美國外國人，只要在美國違法，哪怕... 美國加州州長紐森2日受訪表示，不贊同川普總統對華徵收高關稅。他強調，「加州不是美國」，願向中國和其他交易夥伴「伸出開放之... 紐約時報報導，川普政府掃蕩非法移民，在各地機場、邊界關閘、其他美國入口港引發焦慮，即使綠卡持有人也面臨許多挑剔；綠卡持有... 川普總統2日在社群媒體「真實社群」(Truth Social)發文表示：「我們將取消哈佛大學免稅資格。他們活該！」稅務及...",
#     "comments": "0"
# }
# {
#     "category": "社會",
#     "subtitle": "社會萬象",
#     "title": "昨就診今「未應門」屍僵…二線四星勤指中心主任猝逝 保一總隊：震驚惋惜",
#     "datetime": "2025-05-04",
#     "link": "https://udn.com/news/story/124222/8716494",
#     "content": "保安警察第一總隊勤務指揮中心主任許泰山，昨曾因腰痛、腹痛等身體不適就醫，隨後返回駐地休息，不料今早被發現跪臥主管寢室浴室，已明顯死亡、有屍僵情形，確切死因有待檢警相驗釐清。  警方調查，62歲許泰山5月2日下班後出現腹痛、腰痛症狀，5月3日凌晨因疼痛前往台北榮總醫院急診，經施打止痛針後返回駐地寢室休息，今早妻子多次致電聯繫許無果，請求保一總隊同仁協助確認狀況。  員警一早9時許到主管寢室外敲門，許卻遲未應門，員警破門後發現許跪臥浴室，呼叫無回應，立即通報119協處，台北市消防局獲報派員到場，救護人員發現許泰山身體出現屍僵情形，已明顯死亡，不送醫，交由警方處理。  轄區北投分局警方獲報派員到場採證，發現現場門窗完好，初步未發現外力介入等異狀，通知家屬配合調查，另報請士林地檢署檢察官相驗，將進一步釐清死因。  據悉，許泰山自警大警佐班第15期畢業，曾在刑事局擔任組長、股長，在保一總隊除主任、科長外，年輕時也曾擔任過小隊長、分隊長、大隊長等職務。  警方初查，許泰山先前無慢性病史，雖周末休假，但昨凌晨就醫後選擇就近回到駐地休息，直至今早被發現前，都未離開駐地，確切死因有待釐清。  保一總隊表示，許泰山平時生活樂觀，工作戮力從公、負責盡職，與同事相處和睦，對於許泰山不幸猝逝，總隊至感震驚惋惜，將全力協助家屬辦理喪葬，依規定處理撫卹事宜。  編輯推薦昨腰痛就診今同仁關心「遲未應門」 保一警官已屍僵  保安警察第一總隊。記者李隆揆／攝影 保安警察第一總隊勤務指揮中心主任許泰山，昨曾因腰痛、腹痛等身體不適就醫，隨後返回駐地休息，不料今早被發現跪臥主管寢室浴室... 桃園市楊梅區驚傳一氧化碳中毒事件，4名年約20多歲的越南籍移工因友人遲遲聯絡不上，昨天晚上被發現全倒臥楊梅青山街的租屋處... 位於台北市北投區的保安警察第一總隊今早9時傳出有警官陳屍寢室，台北市消防局獲報派員到場，發現現場是保一總隊勤務指揮中心主... 保安警察第一總隊勤務指揮中心主任許泰山，今早被發現陳屍主管寢室，由於他昨日曾身體不適就醫，警方初步不排除死因與身體因素有... 桃園市楊梅區年約20多歲的越南籍移工、學生男女4人，昨晚友人多日聯繫不到上門找人，發現4 男女倒臥屋內報警，警、消趕到發... 國3北上約358.6公里處台南關廟段昨深夜11點多發生一起自撞死亡車禍，46歲黃姓男子駕駛保時捷跑車行經該路段時，疑不明原因...",
#     "comments": "0"
# }
# {
#     "category": "社會",
#     "subtitle": "社會萬象",
#     "title": "當自己家車子？敞篷保時捷跑車太吸睛 陌生男女擅闖「體驗」挨批",
#     "datetime": "2025-05-04",
#     "link": "https://udn.com/news/story/124222/8716495",
#     "content": "桃園市大溪百吉地區一家餐廳戶外用餐區，盧姓男子駕駛白色敞篷保時捷跑車停車用餐，一對男女打開保時捷進入車內乘坐體驗，盧男PO網質疑男女進入駕駛座行為是好奇？還是意圖行竊？引起網友熱議，警方今天說，警方獲悉詢問盧男是否提告，盧男指該車主為友人，將詢問是否提告。  盧姓男子表示，他的保時捷964跑車停在私人土地上，2名男女未經允許打開車門、坐進車內，男生坐主駕、女生坐副駕，過程被監視器拍下，這可能涉及非法侵入、毀損或竊盜未遂，車子沒鎖，不代表可以進去「看看」，請尊重別人的財產與界線。  盧男PO網後引起網友熱議，有的網友說，「誇張喔…，真的很不尊重人！希望找出後要他們道歉」，網友批評，「太沒水準了」，還有網友勸告車主說，「下次記得上鎖」。  警方表示，盧姓男子駕駛敞篷保時捷跑車前往大溪復興路二段一家餐廳的戶外用餐區停車用餐，被一對男女打開車門進入，監視器全程拍下，該男女行為涉及侵入住居罪、毀損罪（若破壞門鎖或內裝）或竊盜罪（若有拿取物品）等刑責，警方聯繫盧男，查出保時捷車主另有其人，盧男未報案、暫未提告。  警方呼籲，民眾未經允許不要隨意開啟或乘坐他人車輛，亦請車主下車後請緊鎖車門，注意車內不要放置貴重物品，貴重物品隨身攜帶。  大溪百吉地區一家餐廳戶外用餐區客人開保時捷停車用餐，遭陌生男子進入乘坐引起熱議。圖／大溪警方提供大溪百吉地區一家餐廳戶外用餐區客人開保時捷停車用餐，遭陌生男子進入乘坐引起熱議。圖／大溪警方提供 保安警察第一總隊勤務指揮中心主任許泰山，昨曾因腰痛、腹痛等身體不適就醫，隨後返回駐地休息，不料今早被發現跪臥主管寢室浴室... 桃園市楊梅區驚傳一氧化碳中毒事件，4名年約20多歲的越南籍移工因友人遲遲聯絡不上，昨天晚上被發現全倒臥楊梅青山街的租屋處... 位於台北市北投區的保安警察第一總隊今早9時傳出有警官陳屍寢室，台北市消防局獲報派員到場，發現現場是保一總隊勤務指揮中心主... 保安警察第一總隊勤務指揮中心主任許泰山，今早被發現陳屍主管寢室，由於他昨日曾身體不適就醫，警方初步不排除死因與身體因素有... 桃園市楊梅區年約20多歲的越南籍移工、學生男女4人，昨晚友人多日聯繫不到上門找人，發現4 男女倒臥屋內報警，警、消趕到發... 國3北上約358.6公里處台南關廟段昨深夜11點多發生一起自撞死亡車禍，46歲黃姓男子駕駛保時捷跑車行經該路段時，疑不明原因...",
#     "comments": "0"
# }
# Skipping article ID 8716496 due to missing title or content.
